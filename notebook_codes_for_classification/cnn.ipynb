# %%
import numpy as np
import cv2
import tensorflow as tf
import os
import pickle

class DigitRecognizer:

    '''This function initializes a CNN/KNN based on the input parameter modeltype'''
    def __init__(self, modeltype):
        self.writeimg = True
        self.modeltype = modeltype
        if modeltype == "CNN":
            try:
                self.model = tf.keras.models.load_model("cnn.hdf5")
            except:
                raise Exception("cnn.hdf5 not found!")
        elif modeltype == "KNN":
            try:
                self.model = pickle.load(open("knn.sav", 'rb'))
            except:
                raise Exception("knn.sav not found!")

    '''This function takes a preprocessed image and
    returns the prediction made on the image by the CNN or KNN based on the modeltype'''
    def make_prediction(self, imgpath):
        try:
            cleanedimg = cv2.imread(imgpath, 0)
        except:
            raise Exception("Invalid Image path!")
        if self.modeltype == "CNN":
            lis = [cleanedimg]
            lis = np.reshape(lis, (1, 28, 28, 1))
            idx = None
            pred = self.model.predict(lis)
            for i in range(len(pred[0])):
                if pred[0][i] > 0:
                    idx = i
                    break
            return idx
        elif self.modeltype == "KNN":
            cleanedimg = cleanedimg.reshape(1, -1)
            prediction = self.model.predict(cleanedimg)[0]
            return prediction

# %%
import  cv2
# make a prediction for a new image.
#from keras.preprocessing.image import load_img
#from keras.preprocessing.image import img_to_array
#from keras.models import load_model
 
# load and prepare the image
def load_image(filename):
	# load the image
	img = load_img(filename, grayscale=True, target_size=(28, 28))
	#img = cv2.imread(filename, 0)
	# convert to array
#            lis = [cleanedimg]
	#img = np.reshape(img, (1, 28, 28, 1))

	img = img_to_array(img)
	# reshape into a single sample with 1 channel
	img = img.reshape(1, 28, 28, 1)
	# prepare pixel data
	img = img.astype('float32')
	img = img / 255.0
	return img
 
# load an image and predict the class
def run_example():
	# load the image
	img = load_image("81img/d_3_3.png")
	# load model
	model = tf.keras.models.load_model("cnn.hdf5")
	# predict the class
	digit = model.predict_classes(img)
	print(digit)
 
# entry point, run the example
run_example()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bf75f9521697> in <module>
#      33
#      34 # entry point, run the example
# ---> 35 run_example()
#
# <ipython-input-6-bf75f9521697> in run_example()
#      25 def run_example():
#      26         # load the image
# ---> 27         img = load_image("81img/d_3_3.png")
#      28         # load model
#      29         model = tf.keras.models.load_model("cnn.hdf5")
#
# <ipython-input-6-bf75f9521697> in load_image(filename)
#       8 def load_image(filename):
#       9         # load the image
# ---> 10         img = load_img(filename, grayscale=True, target_size=(28, 28))
#      11         #img = cv2.imread(filename, 0)
#      12         # convert to array
#
# NameError: name 'load_img' is not defined

# %%
    '''This function initializes a CNN/KNN based on the input parameter modeltype'''

model = tf.keras.models.load_model("cnn.hdf5")

imgpath = "test.png"
cleanedimg = cv2.imread(imgpath, 0)
print(np.shape(cleanedimg))

lis = [cleanedimg]
lis = np.reshape(lis, (1, 28, 28, 1))
idx = None
pred = self.model.predict(lis)
for i in range(len(pred[0])):
        if(pred[0][i] > 0):
            idx = i
            break
print(idx)
# Out:
# (298, 300)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-f379094c4601> in <module>
#       8
#       9 lis = [cleanedimg]
# ---> 10 lis = np.reshape(lis, (1, 28, 28, 1))
#      11 idx = None
#      12 pred = self.model.predict(lis)
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     299            [5, 6]])
#     300     """
# --> 301     return _wrapfunc(a, 'reshape', newshape, order=order)
#     302
#     303
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# ...

# %%
import numpy as np
img = load_img("81img/d_1_1.png", grayscale=True, target_size=(28, 28))
print(np.shape(img))
plt.imshow(img,cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# (28, 28)

# %%
import numpy as np
import cv2
import tensorflow as tf
import os
import pickle
#from keras.preprocessing.image import load_img

import matplotlib.pyplot as plt

def make_prediction( imgpath):
    #cleanedimg = cv2.imread("81img/d_1_1.png", grayscale=True, target_size=(28, 28))
    cleanedimg = cv2.imread(imgpath, 0)
    lis = [cleanedimg]
    
    lis = np.resize(lis,(28,28))
    print(np.shape(cleanedimg))
    plt.imshow(cleanedimg,cmap='gray', vmin=0, vmax=255)
    model = tf.keras.models.load_model("cnn.hdf5")
    
    lis = np.reshape(lis, (1, 28, 28, 1))
    lis = lis.astype('float32')
    idx = None
    pred = model.predict_classes(lis)
    
    for i in range(len(pred[0])):
        if pred[0][i] > 0:
            idx = i
            break
            
    return idx


modeltype = "CNN"
print(make_prediction('81img/d_4_6.jpeg'))   
#print(make_prediction('test.png'))
# Out:
# (28, 28)
# WARNING:tensorflow:From <ipython-input-7-677fe9e33a59>:23: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-677fe9e33a59> in <module>
#      32
#      33 modeltype = "CNN"
# ---> 34 print(make_prediction('81img/d_4_6.jpeg'))
#      35 #print(make_prediction('test.png'))
#
# <ipython-input-7-677fe9e33a59> in make_prediction(imgpath)
#      23     pred = model.predict_classes(lis)
#      24
# ...

# %%
import matplotlib.pyplot as plt
model = tf.keras.models.load_model("cnn.hdf5")
for i in range(0,9):
    for j in range(0,9):
        
        imgpath = "81img/d_"+str(i)+"_"+str(j)+".jpeg"

        cleanedimg = cv2.imread(imgpath, 0)
        copy = cleanedimg.copy()
        print(np.shape(cleanedimg))

#cleanedimg = np.reshape(cleanedimg,(28,28))
#print(np.shape(cleanedimg))
        temp = cleanedimg.reshape(1, -1)
        s = np.sum(temp)
        
        
        if(s > 7*255):
            print(imgpath)
            lis = [cleanedimg]
    
            lis = np.resize(lis,(28,28))
            print(np.shape(cleanedimg))
            plt.imshow(cleanedimg,cmap='gray', vmin=0, vmax=255)
            #model = tf.keras.models.load_model("cnn.hdf5")
    
            lis = np.reshape(lis, (1, 28, 28, 1))
            lis = lis.astype('float32')
            idx = None
            pred = model.predict_classes(lis)
            print(pred[0])

            
            
            print("lol")
            plt.imshow(copy,cmap='gray', vmin=0, vmax=255)
            plt.show()
            
            
#print((cleanedimg)
# Out:
# (28, 28)
# (28, 28)
# 81img/d_0_1.jpeg
# (28, 28)
# 4
# lol
# (28, 28)
# 81img/d_0_2.jpeg
# (28, 28)
# 4
# lol
# (28, 28)
# 81img/d_0_3.jpeg
# (28, 28)
# 2
# lol
# (28, 28)
# 81img/d_0_4.jpeg
# (28, 28)
# 4
# lol
# (28, 28)
# 81img/d_0_5.jpeg
# (28, 28)
# 2
# lol
# (28, 28)
# 81img/d_0_6.jpeg
# (28, 28)
# 2
# lol
# (28, 28)
# 81img/d_0_7.jpeg
# (28, 28)
# 4
# lol
# (28, 28)
# (28, 28)
# 81img/d_1_0.jpeg
# (28, 28)
# 7
# lol
# (28, 28)
# (28, 28)
# 81img/d_1_2.jpeg
# (28, 28)
# 6
# lol
# (28, 28)
# 81img/d_1_3.jpeg
# (28, 28)
# 4
# lol
# (28, 28)
# 81img/d_1_4.jpeg
# (28, 28)
# 3
# lol
# (28, 28)
# 81img/d_1_5.jpeg
# (28, 28)
# 3
# lol
# (28, 28)
# 81img/d_1_6.jpeg
# (28, 28)
# 2
# lol
# (28, 28)
# 81img/d_1_7.jpeg
# (28, 28)
# 2
# lol
# (28, 28)
# 81img/d_1_8.jpeg
# (28, 28)
# 8
# lol
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# 81img/d_2_4.jpeg
# (28, 28)
# 2
# lol
# (28, 28)
# 81img/d_2_5.jpeg
# (28, 28)
# 5
# lol
# (28, 28)
# 81img/d_2_6.jpeg
# (28, 28)
# 7
# lol
# ...

# %%
import matplotlib.pyplot as plt
model = tf.keras.models.load_model("cnn.hdf5")
(i,j) = (6,3)
imgpath = "81img/d_"+str(i)+"_"+str(j)+".jpeg"
cleanedimg = cv2.imread(imgpath, 0)
copy = cleanedimg.copy()
print(np.shape(cleanedimg))

#cleanedimg = np.reshape(cleanedimg,(28,28))
#print(np.shape(cleanedimg))
temp = cleanedimg.reshape(1, -1)
s = np.sum(temp)
        
        
if(s > 7*255):
    print(imgpath)
    lis = [cleanedimg]
    lis = np.resize(lis,(28,28))
    print(np.shape(cleanedimg))
    plt.imshow(cleanedimg,cmap='gray', vmin=0, vmax=255)
        #model = tf.keras.models.load_model("cnn.hdf5")
    
    lis = np.reshape(lis, (1, 28, 28, 1))
    lis = lis.astype('float32')
    idx = None
    pred = model.predict_classes(lis)
    print(pred[0])

            
            
    print("lol")
    plt.imshow(copy,cmap='gray', vmin=0, vmax=255)
    plt.show()
            
            
#print((cleanedimg)
# Out:
# (28, 28)
# 81img/d_6_3.jpeg
# (28, 28)
# 2
# lol
